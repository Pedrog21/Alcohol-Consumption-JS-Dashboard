# %%
import json
import pandas as pd

df = pd.read_csv('./radarChart.csv')

# %%
df
# Out:
#       classifi  pratica  audi521  inialcoo pibpercapita
# 0            3        4        2         5     15.152,8
# 1            2        4        1         9     15.152,8
# 2            2        4        2         5     15.152,8
# 3            2        4        3         3     15.152,8
# 4            4        4        3         4     15.152,8
# 5            4        2        1         9     15.152,8
# 6            2        2        1         9     15.152,8
# 7            4        9        3         4     15.152,8
# 8            2        2        5         1     15.152,8
# 9            2        3        1         4     15.152,8
# 10           4        3        1         9     15.152,8
# 11           2        4        2         4     15.152,8
# 12           2        3        1         5     15.152,8
# 13           2        3        1         4     15.152,8
# 14           1        4        5         5     15.152,8
# 15           2        4        2         4     15.152,8
# ...

# %%
json_data = df.to_json()

# %%
with open('python_data.json', 'w') as outfile:
    json.dump(json_data, outfile)
